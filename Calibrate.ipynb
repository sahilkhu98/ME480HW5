# %%
from solid import *
from solid.utils import *
import viewscad
import sys

r = viewscad.Renderer(openscad_exec='C:\Program Files\OpenSCAD\openscad.exe')
cyl1 = cylinder(r=10,h=12)
cyl2 = cylinder(r=5,h=12)
cyl3 = cyl1-cyl2

# %%
from solid import *
from solid.utils import *
import viewscad
import sys

r = viewscad.Renderer(openscad_exec='C:\Program Files\OpenSCAD\openscad.exe')

#Make Cylinder
def hole(outerD,innerD,h):
    cyl1 = cylinder(d=outerD,h=12)
    cyl2 = cylinder(d=innerD,h=12)
    cyl3 = cyl1-cyl2
    r.render(c3)

#Making sure diameters are valid
while True:
    n = 1
    try:
        innerD = float(input('Inner Diameter: '))
        pass
    except ValueError:
        print('Value Invalid')
        n = 0
    try:
        outerD = float(input('Outer Diameter: '))
        pass
    except ValueError:
        print('Value Invalid')
        n = 0
    if innerD>=outerD:
        print('Outer Diameter must be larger than Inner Diameter')
        break
    if n==0:
        print('Invalid Diameter Value')
        break
    hole(outterD,innerD,12)
    break

# %%
from solid import *
from solid.utils import *
import viewscad
import sys
import numpy as np
r = viewscad.Renderer(openscad_exec='C:\Program Files\OpenSCAD\openscad.exe')

innerDs = [5,3,2] #Inner Diameters
wallt = [4,2,3] #wall thickness

def cyldr(inrD,wallt):
    length = len(inrD)
    c = []
    outrD = []
    inn = []
    out = []
    slid = 0
    for r in range(length):
        outrD.append(inrD[r]+2*wallt[r])
        out.append(cylinder(d=outrD[r],h=5))
        inn.append(cylinder(d=inrD[r],h=5))
        c += (right(slid)(out[r]))
        c -= (right(slid)(inn[r]))
        slid += outrD[r]/2
    r.render(c)
cyldr(inrD,wallt)

# %%
from solid import *
from solid.utils import *
import viewscad
import sys
import numpy as np

r = viewscad.Renderer(openscad_exec='C:\Program Files\OpenSCAD\openscad.exe')

h = 5
D = [4.5,4.6,4.7,4.8,4.9]
sepD = 6

def LBase(sepD,D,h):
    baseL = sum(D)-(D[0]/2)-(D[-1]/2)+ sepD*(len(D)-1)
    baseH = 0.3*h
    baseW = max(D)*1.3
    seg = 128
    cyl1 = cylinder(d = baseW, h = baseH, segments = seg )
    cyl2 = (translate([0,baseL,0]))(cylinder(d = baseW, h = baseH, segments = seg ))
    cyl = hull()(cyl1,cyl2)
    pos = 0
    n = 0
    
    for t in range(len(D)):
        if t == (len(D)-1):
            c+= (translate([0,baseL,0]))(cylinder(d = D[t], h = h, segments = seg ))
        else:
            c+= (translate([0,pos,0]))(cylinder(d = D[t], h = h, segments = seg ))
            pos += (D[t]/2)+(D[t+1]/2)+sepD
    print(scad_render(c))
LBase(sepD,D,h)
